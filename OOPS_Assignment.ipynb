# %% [markdown]
# Q. What is Object-Oriented Programming (OOP)?
#
#    Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to represent data and methods. It's based on the concept of organizing software around real-world objects or entities, with each object containing both data (attributes) and behavior (methods or functions).
#
#    The main principles are as follow
#
#    1: Encapsulation: This refers to the bundling of data (attributes) and methods (functions) that operate on that data into a single unit, called a class.
#
#    2: Abstraction: Abstraction involves hiding complex implementation details and providing a simplified interface for interacting with the object
#
#    3: Inheritance: This allows a new class (child or subclass) to inherit properties and behaviors (methods) from an existing class
#
#    4:Polymorphism: Polymorphism allows objects of different classes to be treated as objects of a common superclass.
#
# Q. What is a class in OOP?
#
#    A class is a blueprint or template for creating objects (instances). It defines the structure and behaviors that the objects created from the class will have.
#
#    A class basically includes Attributes(Data and variable) and methods(function).
#
# Q: What is an object in OOP?
#
#    An object is an instance of a class. Once a class is defined, you can create objects from that class. An object represents a specific entity in your program and has its own state and behavior based on the class definition.
#
# Q: What is the difference between abstraction and encapsulation?
#
#    Abstraction is about simplifying and hiding complexity by exposing only essential features and operations.
#
#    Encapsulation is about bundling data and methods together and restricting direct access to an objects internal state, allowing controlled interaction via methods.
#
# Q: What are dunder methods in Python?
#
#    Dunder methods (short for "double underscore" methods) in Python are special methods that start and end with double underscores, like __init__, __str__, __add__, etc. These methods are used to define how objects of a class behave in certain situations, such as when they are printed, compared, or interacted with using operators.
#
# Q: Explain the concept of inheritance in OOP?
#
#    Inheritance is one of the core principles of Object-Oriented Programming (OOP) that allows one class (called a child or subclass) to inherit the attributes and methods from another class (called a parent class). Inheritance allows the code to reuse and the creation of hierarchical relationships between classes.
#
# Q: What is polymorphism in OOP?
#
#    Polymorphism in OOP allows objects of different types to be treated as objects of a common superclass. It enables you to define methods that work in many different ways depending on the objects actual type. This promotes flexibility, reusability, and easier maintenance in your code.
#
# Q: How is encapsulation achieved in Python?
#
#    Encapsulation in Object-Oriented Programming (OOP) refers to the bundling of data (attributes) and methods (functions) that operate on that data into a single unit, typically a class. It also involves restricting direct access to some of an object's attributes or methods to prevent unintended interference or modification of the object's state.
#
# Q: What is a constructor in Python?
#
#    A constructor in Python is a special method that is automatically called when a new object of a class is created. Its primary purpose is to initialize the object's attributes and set up its initial state. In Python, the constructor is defined using the __init__ method, which is a dunder (double underscore) method.
#
# Q: What are class and static methods in Python?
#
#    1. Class Methods:
#
#        A class method is a method that is bound to the class, not an instance of the class. It can modify the class state that applies to all instances of the class, but it cannot access instance-specific data    (i.e., instance attributes). Class methods take at least one argument, which is typically called cls, referring to the class itself.
#
#    2. Static Methods:
#        A static method is a method that does not take self or cls as its first argument, and it is bound to the class rather than an instance. Static methods cannot modify object state (instance variables) or class state (class variables). They are mainly used for utility functions that are related to the class but don’t need access to the class or instance.
#
# Q: What is method overloading in Python?
#
#   Method overloading is a concept that allows you to define multiple methods with the same name but different parameters (such as different numbers or types of arguments). In many languages like Java or C++, method overloading is natively supported.
#
#   Python doesn't directly support method overloading, but you can achieve similar functionality using default arguments, variable-length arguments, or by manually checking the types and numbers of arguments passed to the method.
#
# Q: What is method overriding in OOP?
#
#   Method overriding in Object-Oriented Programming (OOP) is a feature that allows a subclass to provide a specific implementation of a method that is already defined in its superclass (parent class). This allows the subclass to redefine or extend the behavior of the inherited method to suit its needs.
#   In Python, method overriding occurs when a subclass defines a method with the same name and signature (parameters) as a method in the parent class.
#
# Q  What is a property decorator in Python?
#
#   In Python, the @property decorator is a built-in function that allows you to define a method in a class that behaves like an attribute. This enables you to define getter methods that can be accessed like attributes, without explicitly calling them as methods.
#
# Q: Why is polymorphism important in OOP?
#
#    Polymorphism is one of the core principles of Object-Oriented Programming (OOP), and it plays a crucial role in making code more flexible, reusable, and maintainable and supports scalability by making it easy to add new features without modifying existing code.
#
# Q: What is an abstract class in Python?
#
#    n abstract class in Python is a class that cannot be instantiated directly and is intended to be subclassed by other classes. It provides a blueprint for other classes, defining methods that must be implemented by its subclasses. Abstract classes are used when you want to define a common interface for a group of related classes but do not want the parent class itself to be used to create objects. Python provides the abc module (Abstract Base Classes) to define abstract classes.
#
# Q: What are the advantages of OOP?
#
#    OOP provides several advantages that make software development easier and more efficient:
#
#    1 Modularity and reusability of code through classes and inheritance.
#    2 Abstraction to hide complexity and focus on essential features.
#    3 Encapsulation to protect data and provide controlled access.
#    4 Inheritance to create new classes based on existing ones.
#    5 Polymorphism to make your code more flexible and reusable.
#    6 Maintainability and scalability for large, complex systems.
#    7 Easier collaboration and improved debugging.
#
# Q: What is the difference between a class variable and an instance variable?
#
#    Class variables are shared across all instances of a class and hold values that are common to all instances.
#
#    Instance variables are unique to each instance and hold values that are specific to that particular instance.
#
#    Both types of variables are essential for modeling different behaviors and attributes in your classes, allowing for flexible and efficient object-oriented designs.
#
# Q: What is multiple inheritance in Python?
#
#    Multiple inheritance in Python is a feature that allows a class to inherit from more than one parent class. This means that a class can have multiple base classes and inherit attributes and methods from all of them. Multiple inheritance is supported natively in Python and allows for more flexible and reusable code.
#
# Q: Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#
#    1. __str__:
#
#       Purpose: The __str__ method is meant to return a human-readable string representation of an object. It is primarily used for display purposes, such as when you call print() or use str() on an object.
#
#       Usage: This method should provide a nice, informal string that describes the object in a way that is easy to understand for users or developers.
#
#   2. __repr__:
#
#       Purpose: The __repr__ method is intended to provide an official string representation of the object that can, ideally, be used to recreate the object. The output of __repr__ should be unambiguous and a valid Python expression if possible. It's often used for debugging, logging, or when you want a precise representation of an object.
#
#       Usage: This method is used primarily for debugging or in situations where you need an accurate, detailed representation of an object.
#
# Q: What is the significance of the ‘super()’ function in Python?
#
#    The super() function in Python is a built-in function that is used to call methods from a parent (or superclass) class. It is especially useful in the context of inheritance, allowing you to access methods and attributes from a parent class without explicitly referring to the parent class name.
#
# Q: What is the significance of the __del__ method in Python?
#
#    The __del__ method in Python is a special method, often referred to as the destructor, that is called when an object is about to be destroyed. It is part of Python's garbage collection mechanism and is typically used to clean up resources that the object may have acquired during its lifetime, such as closing files, releasing network connections, or freeing up memory that is not automatically managed by Python.
#
# Q: What is the difference between @staticmethod and @classmethod in Python?
#
#    @staticmethod - A static method doesn't take a reference to the instance or class (no self or cls argument). It's essentially a regular function that's included in a class for organizational purposes.
#    Typically used for utility functions that don't modify class or instance state but logically belong to the class.
#    When the method doesn't need access to the instance or class but is still logically related to the class.
#
#    @classmethod - A class method takes a reference to the class as its first argument (cls), not the instance. It can access or modify the class state.
#    Used when you need to operate on class-level data or perform actions related to the class itself rather than individual instances.
#    When the method needs to access or modify class-level data or behavior, or when it's related to the class as a whole.
#
# Q: How does polymorphism work in Python with inheritance?
#
#    Polymorphism in Python, especially in the context of inheritance, allows objects of different classes to be treated as objects of a common base class. This is a powerful concept in object-oriented programming (OOP) that enables methods to be used interchangeably, even if they are implemented differently in different classes.
#
# Q: What is method chaining in Python OOP?
#
#    Method chaining in Python (or in object-oriented programming in general) refers to the practice of calling multiple methods on the same object in a single line of code, one after the other. This is made possible by having each method return the object itself, or a reference to the same object, allowing subsequent method calls to be "chained" together.
#
# Q: What is the purpose of the __call__ method in Python?
#
#    The __call__ method in Python allows instances of a class to be invoked like functions.
#    It provides flexibility and the ability to define custom behavior when an object is "called".
#    Common use cases include function objects, callbacks, event handlers, and decorators.

# %%
from os import name
#Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".

class Animal():
 def Speak(self):
   print("Animal sound")
class Dog(Animal):
 def Speak(self):
   print("Bark")

animal = Animal()
dog = Dog()
animal.Speak()
dog.Speak()


#Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
 def __init__(self, radius):
  self.radius = radius
 def area(self):
  return math.pi * self.radius ** 2

class Rectangle(Shape):
 def __init__(self, height, width):
  self.height = height
  self.width = width
 def area(self):
  return self.width*self.height

circle = Circle(6)
rect = Rectangle(8, 7)
circle.area()
rect.area()

print(f"Area of circle: {circle.area():.2f}")
print(f"Area of rectangle: {rect.area()}")

# Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute.

class Vehicle():
 def __init__(self, type):
  self.type = type
class Car(Vehicle):
    def __init__(self, vehicle_type, model):
        super().__init__(vehicle_type)
        self.model = model

    def display_info(self):
        super().display_info()
        print(f"Car Model: {self.model}")

class ElectricCar(Car):
    def __init__(self, vehicle_type, model, battery_capacity):
        super().__init__(vehicle_type, model)
        self.battery_capacity = battery_capacity

    def display_info(self):
        super().display_info()
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, initial_balance=0):
        self._balance = initial_balance

class deposite(BankAccount):
    def __init__(self, amount_deposited):
        self.type = amount_deposited
        print("The amount is deposited")

class withdraw(BankAccount):
    def __init__(self, withdrawl_amount):
        self.type = withdrawl_amount
        print("The amount is withdrawn")

class check_balance(BankAccount):
    def __init__(self, balance):
        self.type = balance
        return self._balance

#Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#and Piano that implement their own version of play().

class Instrument:
  def play(self):
   pass

class Guitar(Instrument) :
  def play(self):
    print("Guitar is playing")

class piano(Instrument):
  def play(self):
   print("Piano is playing")

#Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers.

class MathOperations():
  def add_numbers(self, num1, num2):
   return num1 + nume2

@staticmethod
def subtract_numbers(self, num1, num2):
 return num1 - num2

#Implement a class Person with a class method to count the total number of persons created.

class Person:
 def count_total(self, count):
  count = 0
  count += 1
  return count

#  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".

class Fraction:
 def __init__(self, numerator, denominator):
  self.numperator = numerator
  self.denominator = denominator
  def __str__(self):
   return f"{self.numerator}/{self.denominator}"

#Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#vectors.

class Vector():
 def __init__(self,x,y):
  self.x = x
  self.y = y
 def add(self,x,y):
  return(self.x + x, self.y + y )

#Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."

class Person():
 def __init__(self, name, age):
  self.name = name
  self.age = age
  def greet(person):
   print("Hello, my name is {self.name} and i am {self.age} years old")

#  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#the average of the grades.

class Student():
  def __init__(self, name, grade):
    self.name = name
    self.grade = grade
    def average_grade(Student):
     return sum(self.grade)/len(self.grade)

#Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
#area.

class Rectangel():
 def __init__(self, lenght, breadth):
  self.lenght = length
  self.breadth = breadth
 def area(Rectangle):
  return (self.lenght*self.breadth)

# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary

class Employee():
 def __init__(self, hours_worked, hourly_rate):
  self.hours_worked = hours_worked
  self.hourly_rate = hourly_rate
  def calculate_salary(Emplyoee):
   return self.hours_worked * self.hourly_rate

class Manager(Employee):
 def __init__(self, hours_worked, hourly_rate, bonus):
  super().__init__(hours_worked, hourly_rate)
  self.bonus = bonus
  def calculate_salary(Manager):
   return super().calculate_salary() + self.bonus

#Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.

class Product():
  def __init__(self, name, price, quantity):
   self.name = name
   self.price = price
   self.quantity = quantity
   def total_price(Product):
    return (self.price*self.quantity)

# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.
  @abstractmethod
  class Animal():
   def __init__(self, animal_name):
    self.animal_name = animal_name
    pass

  class Cow(Animal):
   def sound(self):
    print ("moow")
class Sheep(Animal):
 def sound(self):
  print("Sheep sound")

#Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.

class Book():
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published
    def get_book_info(self):
      return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.

class House():
  def __init__(self, add, price):
    self.add = add
    self.price = price
    class Mansion(House):
      def __init__(self, add, price, no_of_rooms):
        super().__init__(add, price)
        self.no_of_rooms = no_of_rooms
        return f"{self.get_house_info()}\nNumber of Rooms: {self.number_of_rooms}"
# Out:
# Animal sound
# Bark
# Area of circle: 113.10
# Area of rectangle: 56
